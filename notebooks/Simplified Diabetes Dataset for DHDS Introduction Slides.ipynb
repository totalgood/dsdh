# %%
from nlpia.loaders import get_data
df = get_data('diabetes')
df.columns = 'age 	sex 	bmi 	bp 	s1 	s2 	s3 	s4 	s5 	s6 	severity'.split()

# %%
df.head(10).round(3)
# Out:
#      age    sex    bmi     bp     s1     s2     s3     s4     s5     s6  \
# 0  0.038  0.051  0.062  0.022 -0.044 -0.035 -0.043 -0.003  0.020 -0.018
# 1 -0.002 -0.045 -0.051 -0.026 -0.008 -0.019  0.074 -0.039 -0.068 -0.092
# 2  0.085  0.051  0.044 -0.006 -0.046 -0.034 -0.032 -0.003  0.003 -0.026
# 3 -0.089 -0.045 -0.012 -0.037  0.012  0.025 -0.036  0.034  0.023 -0.009
# 4  0.005 -0.045 -0.036  0.022  0.004  0.016  0.008 -0.003 -0.032 -0.047
# 5 -0.093 -0.045 -0.041 -0.019 -0.069 -0.079  0.041 -0.076 -0.041 -0.096
# 6 -0.045  0.051 -0.047 -0.016 -0.040 -0.025  0.001 -0.039 -0.063 -0.038
# 7  0.064  0.051 -0.002  0.067  0.091  0.109  0.023  0.018 -0.036  0.003
# 8  0.042  0.051  0.062 -0.040 -0.014  0.006 -0.029 -0.003 -0.015  0.011
# 9 -0.071 -0.045  0.039 -0.033 -0.013 -0.035 -0.025 -0.003  0.068 -0.014
#
#    severity
# 0     151.0
# 1      75.0
# 2     141.0
# 3     206.0
# 4     135.0
# 5      97.0
# 6     138.0
# 7      63.0
# 8     110.0
# 9     310.0

# %%
df['age sex bmi bp severity'.split()]
# Out:
#           age       sex       bmi        bp  severity
# 0    0.038076  0.050680  0.061696  0.021872     151.0
# 1   -0.001882 -0.044642 -0.051474 -0.026328      75.0
# 2    0.085299  0.050680  0.044451 -0.005671     141.0
# 3   -0.089063 -0.044642 -0.011595 -0.036656     206.0
# 4    0.005383 -0.044642 -0.036385  0.021872     135.0
# 5   -0.092695 -0.044642 -0.040696 -0.019442      97.0
# 6   -0.045472  0.050680 -0.047163 -0.015999     138.0
# 7    0.063504  0.050680 -0.001895  0.066630      63.0
# 8    0.041708  0.050680  0.061696 -0.040099     110.0
# 9   -0.070900 -0.044642  0.039062 -0.033214     310.0
# 10  -0.096328 -0.044642 -0.083808  0.008101     101.0
# 11   0.027178  0.050680  0.017506 -0.033214      69.0
# 12   0.016281 -0.044642 -0.028840 -0.009113     179.0
# 13   0.005383  0.050680 -0.001895  0.008101     185.0
# 14   0.045341 -0.044642 -0.025607 -0.012556     118.0
# 15  -0.052738  0.050680 -0.018062  0.080401     171.0
# ...
